# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    # for filename in filenames:
    #     print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
#   File "/tmp/ipykernel_58/450492078.py", line 22
#     import kagglehub
#     ^
# IndentationError: expected an indented block after 'for' statement on line 12

# %%
import matplotlib.pyplot as plt 
from PIL import Image
path=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/train/banana/saltandpepper_Screen Shot 2018-06-12 at 9.47.32 PM.png"

image = Image.open(path)

plt.imshow(image)
plt.axis("off")
plt.show()

# %%
import cv2
path=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/train/rottenapples/rotated_by_30_Screen Shot 2018-06-08 at 2.36.31 PM.png"
image=cv2.imread(path)
image=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
path1=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test/rottenoranges/rotated_by_75_Screen Shot 2018-06-12 at 11.45.57 PM.png"
imag1=Image.open(path1)
plt.imshow(imag1)
plt.axis('off')
plt.show()

# %%
path=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test/rottenbanana/vertical_flip_Screen Shot 2018-06-12 at 9.05.08 PM.png"
image2=cv2.imread(path)
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)
plt.imshow(image2)
plt.axis('off')
plt.show()

# %%
path=r'/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1'

# %%
classes = os.listdir(path)

print(classes)
# Out:
# ['test', 'train']

# %%
test_path=path+"/test"

# %%
classes1 = os.listdir(test_path)

print(classes1)
# Out:
# ['rottenbanana', 'orange', 'apple', 'rottenoranges', 'rottenapples', 'banana']

# %%
train_path=path+"/train"
classs2=os.listdir(train_path)
print(classs2)
# Out:
# ['rottenbanana', 'orange', 'apple', 'rottenoranges', 'rottenapples', 'banana']

# %%
total_image_of_apple_test=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test/apple"
images_apple_test=os.listdir(total_image_of_apple_test)
print(f"total image of fresh apple in test image is,{len(images_apple_test)}")
# Out:
# total image of fresh apple in test image is,263

# %%
total_image_of_apple_train=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/train/apple"
images_apple_train=os.listdir(total_image_of_apple_train)
print(f"total image of fresh apple in test image is,{len(images_apple_train)}")
# Out:
# total image of fresh apple in test image is,1442

# %%
total_image_of_apple_test=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test/rottenapples"
print(f"total image of rotten  apple in test image is,{len(images_apple_test)}")
# Out:
# total image of rotten  apple in test image is,263

# %%
imagePath = r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test/apple/rotated_by_15_Screen Shot 2018-06-08 at 5.00.35 PM.png"
imagePath=Image.open(imagePath)
print(f"The size of the image is {imagePath.size}")
print(f"The mode of the image is {imagePath.mode}")
# Out:
# The size of the image is (416, 448)
# The mode of the image is RGB

# %%
from PIL import Image
import os

imagePath = r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test/apple"

# folder ke andar first image ka naam
image_name = os.listdir(imagePath)[0]

# complete image path
image_path = os.path.join(imagePath, image_name)

# image open
image = Image.open(image_path)

print(f"The image name is: {image_name}")
print(f"The size of the apple image is: {image.size}")
print(f"The mode of the apple image is: {image.mode}")
# Out:
# The image name is: translation_Screen Shot 2018-06-08 at 5.03.17 PM.png
# The size of the apple image is: (376, 380)
# The mode of the apple image is: RGB

# %%
classes1_test = os.listdir(test_path)

print(classes1)
# Out:
# ['rottenbanana', 'orange', 'apple', 'rottenoranges', 'rottenapples', 'banana']

# %%
for class_name in classes1:
    image_name = os.listdir(imagePath)[0]
    image_path = os.path.join(imagePath, image_name)
    image = Image.open(image_path)
print(class_name, "→", image.size, image.mode)
# Out:
# banana → (376, 380) RGB

# %%
### the size of the image is different so that we can resize  it in (224,224,3)
import tensorflow as tf

train_path = r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/train"

train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_path,
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 9453 files belonging to 6 classes.

# %%
for images, labels in train_dataset.take(1):
    print("Image shape:", images.shape)
    print("Label shape:", labels.shape)
# Out:
# Image shape: (32, 224, 224, 3)
# Label shape: (32,)

# %%
test_path=r"/kaggle/input/datasets/user2036/fruit-freshness-dataset-v1/test"
test_dataset=tf.keras.utils.image_dataset_from_directory(
    test_path,image_size=(224,224),
    batch_size=32
)
# Out:
# Found 1879 files belonging to 6 classes.

# %%
import os

print("Train classes:")
print(sorted(os.listdir(train_path)))

print("Test classes:")
print(sorted(os.listdir(test_path)))
# Out:
# Train classes:
# ['apple', 'banana', 'orange', 'rottenapples', 'rottenbanana', 'rottenoranges']
# Test classes:
# ['apple', 'banana', 'orange', 'rottenapples', 'rottenbanana', 'rottenoranges']

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
val_dataset = val_dataset.map(
    lambda x, y: (normalization_layer(x), y)
)

test_dataset = test_dataset.map(
    lambda x, y: (normalization_layer(x), y)
)

# %%
# for images, labels in test_dataset.take(1):
#     print("Shape:", images.shape)
#     print("Minimum:", tf.reduce_min(images).numpy())
#     print("Maximum:", tf.reduce_max(images).numpy())

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    
    Conv2D(32, (3,3), activation="relu",
           input_shape=(224,224,3)),
    
    MaxPooling2D((2,2)),
    
    Conv2D(64, (3,3), activation="relu"),
    
    MaxPooling2D((2,2)),
    
    Flatten(),
    
    Dense(128, activation="relu"),
    
    Dense(6, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 186624)         │             0 │
# ...

# %%
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=10
)
# Out:
# Epoch 1/10
# 2026-09-20 16:59:55.366627: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-20 16:59:55.514891: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   3/296 ━━━━━━━━━━━━━━━━━━━━ 11s 40ms/step - accuracy: 0.1406 - loss: 4272.2748
# I0000 00:00:1789923598.384253     140 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.2755 - loss: 536.5398
# ...

# %%
test_loss, test_accuracy = model.evaluate(test_dataset)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 7s 119ms/step - accuracy: 0.3896 - loss: 2.3066
# Test Loss: 2.306626558303833
# Test Accuracy: 0.38956892490386963

# %%
import numpy as np

y_true = []
y_pred = []

for images, labels in test_dataset:
    predictions = model.predict(images, verbose=0)
    
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_true, y_pred)

print(cm)
# Out:
# [[ 82  15  18 105  13  30]
#  [ 12  60  19  70  76  11]
#  [ 25  27  50 102  17  54]
#  [ 65  16  23 216  23  83]
#  [ 16  53   7  46 249  17]
#  [ 26  15  29 109  25  75]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(cm, annot=True, fmt='d')

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
